# %%
import pandas as pd
import matplotlib.pyplot as plt
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data = pd.read_csv('spreadData_3s_poll_01.csv')
data.iloc[:,2:3].plot(figsize = (18, 4))

# %%
data = pd.read_csv('spreadData_1s_poll_01.csv')
data.iloc[:,2:3].plot(figsize = (18, 4))

# %%
data = pd.read_csv('spreadData_100ms_poll_01.csv')
data.iloc[:,2:3].plot(figsize = (18, 4))

# %%
data = pd.read_csv('spreadData.csv')
data.iloc[:,2:3].plot(figsize = (18, 4))

# %%
data = pd.read_csv('spreadData_aws_01.csv')
data.iloc[:,2:3].head(1800).plot(figsize = (18, 4))

# %%
data = pd.read_csv('spreadData.csv').head(10000)
data.columns = ['exchange_id', 'ts', 'trade_type', 'price']
data.size
# Out:
# 40000

# %%
joined = pd.merge(
    left = data.where(data.trade_type == 'BUY'), \
    right = data.where(data.trade_type == 'SELL'), \
    how = 'inner', \
    on = 'ts' \
)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-3b079cf38a75> in <module>()
#       5     on = 'ts' \
#       6 )
# ----> 7 joined.price_x.distinct
#
# /usr/local/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'distinct'

# %%
joined.trade_type_y.unique()
# Out:
# array(['SELL', nan], dtype=object)
